# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm 
from mpl_toolkits.mplot3d import Axes3D

# %%
X = np.linspace(-400, 400, 100)     
Y = np.linspace(-400, 400, 100)     
X, Y = np.meshgrid(X, Y) 

Z = ((0.002*X)**2 - 100 * np.sin(0.02*np.pi * X)) + ((0.002*Y)**2 - 100 * np.cos(0.02*np.pi * Y))

# %%
plt.imshow(Z)
plt.show()

# %%
fig = plt.figure() 
ax = fig.gca(projection='3d') 
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
  cmap=cm.nipy_spectral, linewidth=0.08,
  antialiased=True)    
# plt.savefig('rastrigin_graph.png')
plt.show()
# Out:
# C:\Users\quang\AppData\Local\Temp\ipykernel_2252\3561154733.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')
