# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
f = [1, 2, -3]
x = 5
y = np.polyval(f,x)
print(x)
print(y)
# Out:
# 5
# 32

# %%
import numpy as np
from matplotlib import pyplot as plt
f = [1, 2, -3]
x = np.linspace(0,10,21);
y = np.polyval(f,x)
plt.plot(x,y,'o-')
