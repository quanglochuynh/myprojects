# %%
import pandas as pd
import numpy as np
import os

data_dir = "./data/"

# %%
list_dir = os.listdir(data_dir)
print(list_dir)
# Out:
# ['fulfilment_center_info.csv', 'meal_info.csv', 'sample_submission.csv', 'test.csv', 'train.csv']

# %%
center_info = pd.read_csv(os.path.join(data_dir,list_dir[0]))
meal_info   = pd.read_csv(os.path.join(data_dir,list_dir[1]))
test_ds     = pd.read_csv(os.path.join(data_dir,list_dir[3]))
train_ds    = pd.read_csv(os.path.join(data_dir,list_dir[4]))

# %%
test_ds
# Out:
#             id  week  center_id  meal_id  checkout_price  base_price  \
# 0      1028232   146         55     1885          158.11      159.11
# 1      1127204   146         55     1993          160.11      159.11
# 2      1212707   146         55     2539          157.14      159.14
# 3      1082698   146         55     2631          162.02      162.02
# 4      1400926   146         55     1248          163.93      163.93
# ...        ...   ...        ...      ...             ...         ...
# 32568  1250239   155         61     1543          482.09      484.09
# 32569  1039516   155         61     2304          483.09      483.09
# 32570  1158107   155         61     2664          322.07      323.07
# 32571  1444235   155         61     2569          322.07      323.07
# 32572  1291286   155         61     2490          276.45      276.45
#
#        emailer_for_promotion  homepage_featured
# 0                          0                  0
# ...
