# %%
import pandas as pd

# %%
df = pd.read_csv("../../../../Desktop/Matrix/tieuchuan.csv", sep=";")

# %%
df
# Out:
#                                                                                                                                          tieuchuan
# NaN          Q1 Q2 Q3 Q4 Q5 Q6 Q7 Q8 Q9 Q10 Q11 Q12 Bình Thạnh Phú Nhuận Gò Vấp Tân Bình Tân Phú Bình Tân Bình Chánh Hóc Môn   Củ Chi
# Q1           15 15 15 15 15 18 15 18 25 15  15  19  15           15          16       15        16       18        15           23              40
# Q2           15 15 15 15 18 18 18 21 20 18  19  24  17           16          19       17        21       22        16           30              50
# Q3           15 15 15 15 15 17 16 17 25 15  15  18  15           15          15       15        15       16        15           21              40
# Q4           15 15 15 15 15 18 15 17 25 15  16  20  16           15          17       16        17       17        16           24              43
# ...

# %%
json = df.to_json(orient='record')
print(json)
