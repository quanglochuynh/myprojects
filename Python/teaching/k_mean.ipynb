# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.cluster import k_means

# %%
df = pd.read_csv("mango2.csv")

# %%
print(df.to_string())
# Out:
#      GreenMango Length  GreenMangowidth  YelloMangoLength  YelloMangoWidth
# 0                 10.2             10.5               5.6              0.6
# 1                  9.8              9.0               5.6              0.6
# 2                  9.4              9.6               5.2              0.6
# 3                  9.2              9.3               6.0              0.6
# 4                 10.0             10.8               5.6              0.6
# 5                 10.8             11.7               6.8              1.2
# 6                  9.2             10.2               5.6              0.9
# 7                 10.0             10.2               6.0              0.6
# 8                  8.8              8.7               5.6              0.6
# 9                  9.8              9.3               6.0              0.3
# 10                10.8             11.1               6.0              0.6
# ...

# %%
data = df.to_numpy()

# %%
data = data[0:150]
print(data)
# Out:
# [[10.2 10.5  5.6  0.6]
#  [ 9.8  9.   5.6  0.6]
#  [ 9.4  9.6  5.2  0.6]
#  [ 9.2  9.3  6.   0.6]
#  [10.  10.8  5.6  0.6]
#  [10.8 11.7  6.8  1.2]
#  [ 9.2 10.2  5.6  0.9]
#  [10.  10.2  6.   0.6]
#  [ 8.8  8.7  5.6  0.6]
#  [ 9.8  9.3  6.   0.3]
#  [10.8 11.1  6.   0.6]
#  [ 9.6 10.2  6.4  0.6]
#  [ 9.6  9.   5.6  0.3]
#  [ 8.6  9.   4.4  0.3]
#  [11.6 12.   4.8  0.6]
#  [11.4 13.2  6.   1.2]
#  [10.8 11.7  5.2  1.2]
#  [10.2 10.5  5.6  0.9]
#  [11.4 11.4  6.8  0.9]
#  [10.2 11.4  6.   0.9]
#  [10.8 10.2  6.8  0.6]
#  [10.2 11.1  6.   1.2]
#  [ 9.2 10.8  4.   0.6]
#  [10.2  9.9  6.8  1.5]
#  [ 9.6 10.2  7.6  0.6]
#  [10.   9.   6.4  0.6]
#  [10.  10.2  6.4  1.2]
#  [10.4 10.5  6.   0.6]
#  [10.4 10.2  5.6  0.6]
#  [ 9.4  9.6  6.4  0.6]
#  [ 9.6  9.3  6.4  0.6]
#  [10.8 10.2  6.   1.2]
#  [10.4 12.3  6.   0.3]
#  [11.  12.6  5.6  0.6]
#  [ 9.8  9.3  6.   0.3]
#  [10.   9.6  4.8  0.6]
#  [11.  10.5  5.2  0.6]
#  [ 9.8  9.3  6.   0.3]
#  [ 8.8  9.   5.2  0.6]
#  [10.2 10.2  6.   0.6]
# ...

# %%
greenH = data[:,0]
print(np.shape(greenH))
greenW = data[:,1]
print(np.shape(greenW))
yellowH = data[:,2]
print(np.shape(yellowH))
yellowW = data[:,3]
print(np.shape(yellowW))
# Out:
# (150,)
# (150,)
# (150,)
# (150,)

# %%
plt.rcParams['figure.figsize'] = (8,6)
plt.scatter(greenH, greenW)
plt.scatter(yellowH, yellowW)
plt.show()
